# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##  Loading Dataset Using Pandas

# %%
df= pd.read_csv("Churn_Modelling.csv")

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %% [markdown]
# ##  Dataset Size

# %%
print("Number of Rows in Dataset: ",df.shape[0])
print("Number of Columns in Dataset: ",df.shape[1])
# Out:
# Number of Rows in Dataset:  10000
# Number of Columns in Dataset:  14

# %% [markdown]
# ##  Statistic Summary

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# ## Deleted Un-necessary Column

# %%
# Drop Surname Variable
df=df.drop(['Surname'] , axis=1)

# %% [markdown]
# Deleted the "Surname" Column

# %%
df.head()
# Out:
#    RowNumber  CustomerId  CreditScore Geography  Gender  Age  Tenure  \
# 0          1    15634602          619    France  Female   42       2
# 1          2    15647311          608     Spain  Female   41       1
# 2          3    15619304          502    France  Female   42       8
# 3          4    15701354          699    France  Female   39       1
# 4          5    15737888          850     Spain  Female   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %% [markdown]
# ## Data Cleaning
#
# 1.   Duplicate value = 0
# 2.   Change Datatype of Variable "Gender" and "Geography"
# 3.   Apply Standardize for numerical feature

# %%
# Drop Duplicate Values
df = df.drop_duplicates()

# %%
# Convert String Data types into Integer
df['Geography'] = df['Geography'].astype('category').cat.codes
df['Gender'] = df['Gender'].astype('category').cat.codes

# %% [markdown]
# Datatype have been changed into integer

# %%
df.head()
# Out:
#    RowNumber  CustomerId  CreditScore  Geography  Gender  Age  Tenure  \
# 0          1    15634602          619          0       0   42       2
# 1          2    15647311          608          2       0   41       1
# 2          3    15619304          502          0       0   42       8
# 3          4    15701354          699          0       0   39       1
# 4          5    15737888          850          2       0   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %%
# Standardize numerical features
from sklearn.preprocessing import StandardScaler
numerical_cols = ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'EstimatedSalary']
scaler = StandardScaler()
df[numerical_cols] = scaler.fit_transform(df[numerical_cols])

# %% [markdown]
# All the Numerical Features have been Standardized

# %% [markdown]
# ## Handling Missing Values

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# There is no null values present in this dataset

# %% [markdown]
# ## Exploratory Data Analyst

# %%
#Histogram for numerical columns
df.hist(bins=30, figsize=(15, 10))
plt.suptitle("Histograms for Numerical Columns")
plt.show()
 # Comment: Histograms show the distribution of numerical columns. Useful for understanding the data spread and detecting outliers.

# %% [markdown]
# ## RowNumber and CustomerId:
#
# These histograms show a uniform distribution, indicating that these columns are likely identifiers and should not be used as features for predictive modeling.
#
# ## CreditScore:
#
# The histogram for CreditScore shows a normal distribution with a peak around the center.
#
# ## Geography:
#
# The histogram for Geography shows discrete values, indicating categorical data.
#
# ## Gender:
#
# This histogram shows the distribution of genders in the dataset, with binary values (0 and 1).
#
# ## Age:
#
# The histogram for Age helping to understand the age demographics in the dataset.
#
# ## Tenure:
#
# The spread indicates how long customers have been with the bank.
#
# ## Balance:
#
# The Balance histogram shows a right-skewed distribution, indicating that most customers have a balance towards the lower end, with fewer customers having a high balance.
#
# ## NumOfProducts:
#
# shows the distribution of the number of products, indicating how many products each customer has.
#
# ## HasCrCard:
#
# shows the distribution of customers who have a credit card (1) and those who do not (0).
#
# ## IsActiveMember:
#
# shows the distribution of active members (1) versus inactive members (0).
#
# ## EstimatedSalary:
#
# The histogram for EstimatedSalary shows a roughly uniform distribution, indicating a wide range of salaries across the dataset.

# %% [markdown]
# ## Detect and Handle Outliers Using IQR method

# %%
def detect_outliers_iqr(df, columns):

  #  Detect and handle outliers using IQR method for specified columns.

    df_cleaned = df.copy()
    outliers_dict = {}

    for col in columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        outliers = (df[col] < (Q1 - 1.5 * IQR)) | (df[col] > (Q3 + 1.5 * IQR))
        outliers_dict[col] = outliers
        df_cleaned = df_cleaned[~outliers]

    return df_cleaned, outliers_dict

def visualize_outliers(df, columns):

#    Visualize outliers using box plots for specified columns.

    for col in columns:
        plt.figure(figsize=(8, 4))
        sns.boxplot(x=df[col])
        plt.title(f"Box Plot of {col}")
        plt.show()

columns_to_check = ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'EstimatedSalary']

# Detect and handle outliers using IQR method
df_cleaned_iqr, outliers_dict = detect_outliers_iqr(df, columns_to_check)
print(f"Number of outliers detected in each column:")
for col, outliers in outliers_dict.items():
    print(f"{col}: {outliers.sum()}")

# Visualize outliers in the original dataset
print("Visualizing outliers in the original dataset:")
visualize_outliers(df, columns_to_check)

# Visualize outliers in the cleaned dataset
print("Visualizing outliers in the cleaned dataset:")
visualize_outliers(df_cleaned_iqr, columns_to_check)
# Out:
# <ipython-input-193-a8e7f1f99be7>:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_cleaned = df_cleaned[~outliers]
# <ipython-input-193-a8e7f1f99be7>:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_cleaned = df_cleaned[~outliers]
# <ipython-input-193-a8e7f1f99be7>:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_cleaned = df_cleaned[~outliers]
# <ipython-input-193-a8e7f1f99be7>:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_cleaned = df_cleaned[~outliers]
# <ipython-input-193-a8e7f1f99be7>:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_cleaned = df_cleaned[~outliers]
# Number of outliers detected in each column:
# CreditScore: 16
# Age: 411
# Tenure: 0
# Balance: 0
# NumOfProducts: 60
# EstimatedSalary: 0
# Visualizing outliers in the original dataset:
# ...

# %% [markdown]
# ## Number of outliers detected in each column:
#
#
# *   CreditScore: 16
# *   Age: 411
# *   Tenure: 0
# *   Balance: 0
# *   NumOfProducts: 60
# *   EstimatedSalary: 0

# %% [markdown]
# ## Count Values in Targeted Column

# %%
df["Exited"].value_counts()
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %% [markdown]
# Data is Imbalance. so first we have to balance our targeted data

# %%
X=df.drop("Exited",axis=1)
y=df["Exited"]

# %% [markdown]
# ## Balancing The Values

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)
X_res, y_res = smote.fit_resample(X, y)
y_res.value_counts()
# Out:
# Exited
# 1    7963
# 0    7963
# Name: count, dtype: int64

# %% [markdown]
# ## Spliting The Dataset

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %% [markdown]
# ## Using KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn= KNeighborsClassifier()
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred=knn.predict(X_test)

# %%
from sklearn.metrics import precision_score,recall_score,f1_score

# %% [markdown]
# ## Precision Score

# %%
precision_score(y_test,y_pred)
# Out:
# 0.23423423423423423

# %% [markdown]
# ## Recall Score

# %%
recall_score(y_test,y_pred)
# Out:
# 0.06615776081424936

# %% [markdown]
# ## F1 Score

# %%
f1_score(y_test,y_pred)
# Out:
# 0.10317460317460317

# %% [markdown]
# ## Precision gave the best prediction value : 23%
